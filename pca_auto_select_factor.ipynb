# %%
import numpy as np
import pandas as pd
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt

dataset=pd.read_csv("data.csv")
dataset.head()
X=StandardScaler().fit_transform(dataset)

# %%
pca=PCA(.90)
principalComponents=pca.fit_transform(X)
Y=pd.DataFrame(data=principalComponents)
Y
# Out:
#              0          1          2         3         4         5         6  \
# 0    16.641965  -4.096815  -0.682972  1.687037  4.799320 -0.627212  1.408269
# 1     0.173261  -2.227705   0.351855 -0.807507 -1.797186  0.613809 -0.484657
# 2    -1.224070   0.663860  -2.641165 -0.656152 -1.026569 -1.205890 -0.063570
# 3     4.323960  -6.100879   1.438225  0.501362  1.505702  2.198168  2.060093
# 4     2.430413  -4.670498   1.293224 -0.259747  0.121734  2.700831  5.499675
# ..         ...        ...        ...       ...       ...       ...       ...
# 316  -4.543688   8.220389  -5.621640 -1.566893  0.917862 -0.960049 -0.064764
# 317  -3.316898   5.649471  -4.563975  1.965652  0.218308 -0.278665 -1.106373
# 318   3.090046  -4.031496  -0.301373  3.953009  0.496017 -1.537793 -1.333962
# 319  -2.992219   4.644782  -4.244260  0.634000 -0.388133 -0.719274 -1.077939
# 320  -5.714063  10.903552 -10.389614 -5.602898  5.238817 -6.706461  0.482422
#
#             7
# 0   -1.822454
# 1    0.605773
# 2    0.125811
# 3   -2.149852
# 4   -0.863238
# ..        ...
# 316 -1.697033
# 317 -1.018404
# 318 -0.233706
# 319 -1.185539
# 320 -3.081554
#
# [321 rows x 8 columns]

# %%
percent_variance = np.round(pca.explained_variance_ratio_* 100, decimals =2)
sum(percent_variance)
# Out:
# 91.44999999999999
